# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import random, os, sys
from datetime import datetime
import time

# %%
# Loading the data set using pandas
df=pd.read_csv("indian_liver_patient.csv", sep=',')

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# std                  182.620356                  288.918529        1.085451
# min                   10.000000                   10.000000        2.700000
# 25%                   23.000000                   25.000000        5.800000
# 50%                   35.000000                   42.000000        6.600000
# 75%                   60.500000                   87.000000        7.200000
# max                 2000.000000                 4929.000000        9.600000
#
#           Albumin  Albumin_and_Globulin_Ratio     Dataset
# count  583.000000                  579.000000  583.000000
# mean     3.141852                    0.947064    1.286449
# std      0.795519                    0.319592    0.452490
# min      0.900000                    0.300000    1.000000
# 25%      2.600000                    0.700000    1.000000
# 50%      3.100000                    0.930000    1.000000
# 75%      3.800000                    1.100000    2.000000
# max      5.500000                    2.800000    2.000000

# %%
df.shape
# Out:
# (583, 11)

# %%
#To check the data types
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %%
#To show the total NULL Values present in the NULL Valued fields
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
fill = df['Albumin_and_Globulin_Ratio']
Albumin_and_Globulin_Ratio = fill.fillna(fill.median(),inplace=True)

# %% [markdown]
# # H2O

# %%
import h2o
from h2o.automl import H2OAutoML
import random, os, sys
from datetime import datetime
import pandas as pd
import logging
import csv
import optparse
import time
import json
from distutils.util import strtobool
import psutil

import warnings
warnings.filterwarnings('ignore')

# %%
port_no=random.randint(5555,55555)
h2o.init(strict_version_check=False,min_mem_size_GB=5,port=port_no)
# Out:
# Checking whether there is an H2O instance running at http://localhost:49023 ..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.201-b09, mixed mode)
#   Starting server from C:\Users\Manvi\Anaconda3\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\Manvi\AppData\Local\Temp\tmpbbqhmuw1
#   JVM stdout: C:\Users\Manvi\AppData\Local\Temp\tmpbbqhmuw1\h2o_Manvi_started_from_python.out
#   JVM stderr: C:\Users\Manvi\AppData\Local\Temp\tmpbbqhmuw1\h2o_Manvi_started_from_python.err
#   Server is running at http://127.0.0.1:49023
# Connecting to H2O server at http://127.0.0.1:49023 ... successful.
# --------------------------  ------------------------------------------
# H2O cluster uptime:         03 secs
# H2O cluster timezone:       America/New_York
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.24.0.1
# H2O cluster version age:    19 days
# H2O cluster name:           H2O_from_python_Manvi_sl63bo
# H2O cluster total nodes:    1
# H2O cluster free memory:    4.792 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://127.0.0.1:49023
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, Algos, AutoML, Core V3, Core V4
# Python version:             3.6.7 final
# --------------------------  ------------------------------------------

# %%
#importing data to the server
df = h2o.import_file(path="indian_liver_patient.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
df.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Age</th><th>Gender  </th><th style="text-align: right;">  Total_Bilirubin</th><th style="text-align: right;">  Direct_Bilirubin</th><th style="text-align: right;">  Alkaline_Phosphotase</th><th style="text-align: right;">  Alamine_Aminotransferase</th><th style="text-align: right;">  Aspartate_Aminotransferase</th><th style="text-align: right;">  Total_Protiens</th><th style="text-align: right;">  Albumin</th><th style="text-align: right;">  Albumin_and_Globulin_Ratio</th><th style="text-align: right;">  Dataset</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">

# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  isNA(Age)</th><th style="text-align: right;">  isNA(Gender)</th><th style="text-align: right;">  isNA(Total_Bilirubin)</th><th style="text-align: right;">  isNA(Direct_Bilirubin)</th><th style="text-align: right;">  isNA(Alkaline_Phosphotase)</th><th style="text-align: right;">  isNA(Alamine_Aminotransferase)</th><th style="text-align: right;">  isNA(Aspartate_Aminotransferase)</th><th style="text-align: right;">  isNA(Total_Protiens)</th><th style="text-align: right;">  isNA(Albumin)</th><th style="text-align: right;">  isNA(Albumin_and_Globulin_Ratio)</th><th style="text-align: right;">  isNA(Dataset)</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# <tr><td style="text-align: right;">          0</td><td style="text-align: right;">             0</td><td style="text-align: right;">                      0</td><td style="text-align: right;">                       0</td><td style="text-align: right;">                           0</td><td style="text-align: right;">                               0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">                     0</td><td style="text-align: right;">              0</td><td style="text-align: right;">                                 0</td><td style="text-align: right;">              0</td></tr>
# </tbody>
# </table>

# %%
target = 'Dataset'
run_time=300
pct_memory=0.5
server_path=None 
data_path=None
all_variables=None
test_path=None
model_path=None
nthreads=1 
name=None 
virtual_memory=psutil.virtual_memory()
min_mem_size=int(round(int(pct_memory*virtual_memory.available)/1073741824,0))
run_id='SOME_ID_20180617_221529' # Just some arbitrary ID
classification=True
scale=False
max_models=None
balance_y=False # balance_classes=balance_y
balance_threshold=0.2
project ="automl_test"
analysis=0

# %%
def alphabet(n):
  alpha='0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'    
  str=''
  r=len(alpha)-1   
  while len(str)<n:
    i=random.randint(0,r)
    str+=alpha[i]   
  return str


def set_meta_data(analysis,run_id,server,data,test,model_path,target,run_time,classification,scale,model,balance,balance_threshold,name,path,nthreads,min_mem_size):
  m_data={}
  m_data['start_time'] = time.time()
  m_data['target']=target
  m_data['server_path']=server
  m_data['data_path']=data 
  m_data['test_path']=test
  m_data['max_models']=model
  m_data['run_time']=run_time
  m_data['run_id'] =run_id
  m_data['scale']=scale
  m_data['classification']=classification
  m_data['scale']=False
  m_data['model_path']=model_path
  m_data['balance']=balance
  m_data['balance_threshold']=balance_threshold
  m_data['project'] =name
  m_data['end_time'] = time.time()
  m_data['execution_time'] = 0.0
  m_data['run_path'] =path
  m_data['nthreads'] = nthreads
  m_data['min_mem_size'] = min_mem_size
  m_data['analysis'] = analysis
  return m_data


def automl(maxruntime,X,Y,df):
    aml = H2OAutoML(max_runtime_secs=maxruntime,exclude_algos = ['DeepLearning', 'StackedEnsemble'])
    aml.train(x=X,y=y,training_frame=df)
    return aml


def dict_to_json(dct,n):  
    j = json.dumps(dct, indent=4)
    f = open(n, 'w')
    print(j, file=f)
    f.close()

# %%
run_id=alphabet(9)
if server_path==None:
  server_path=os.path.abspath(os.curdir)
os.chdir(server_path) 
run_dir = os.path.join(server_path,run_id)
os.mkdir(run_dir)
os.chdir(run_dir)    

# run_id to std out
print (run_id)
# Out:
# nRidYg95h

# %%
# meta data
meta_data = set_meta_data(analysis, run_id,server_path,data_path,test_path,model_path,target,run_time,classification,scale,max_models,balance_y,balance_threshold,name,run_dir,nthreads,min_mem_size)
print(meta_data)
# Out:
# {'start_time': 1555807173.0831306, 'target': 'Dataset', 'server_path': 'C:\\Users\\Manvi\\Anaconda3\\indian-liver-patient-records', 'data_path': None, 'test_path': None, 'max_models': None, 'run_time': 300, 'run_id': 'nRidYg95h', 'scale': False, 'classification': True, 'model_path': None, 'balance': False, 'balance_threshold': 0.2, 'project': None, 'end_time': 1555807173.0831306, 'execution_time': 0.0, 'run_path': 'C:\\Users\\Manvi\\Anaconda3\\indian-liver-patient-records\\nRidYg95h', 'nthreads': 1, 'min_mem_size': 0, 'analysis': 0}

# %%
y = target
X=[name for name in df.columns if name != y]
print(X)
print(y)
# Out:
# ['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase', 'Alamine_Aminotransferase', 'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio']
# Dataset

# %%
meta_data['X']=X  
model_start_time = time.time()

# %%
if analysis == 3:
  classification=False
elif analysis == 2:
  classification=True
elif analysis == 1:
  classification=True

# %%
if classification:
    df[y] = df[y].asfactor()

# %%
classification=True
if classification:
    print(df[y].levels())
# Out:
# [['1', '2']]

# %% [markdown]
# # Runtime: 300sec

# %%
aml2 = automl(300,X,y,df)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
meta_data['run_time'] = 300
meta_data['end_time'] = time.time()
meta_data['execution_time'] = meta_data['end_time'] - meta_data['start_time']

# %%
aml2.leaderboard
# Out:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mse</th></tr>
# </thead>
# <tbody>
# <tr><td>GBM_grid_1_AutoML_20190420_204025_model_4          </td><td style="text-align: right;">0.770397</td><td style="text-align: right;"> 0.533106</td><td style="text-align: right;">              0.303151</td><td style="text-align: right;">0.418952</td><td style="text-align: right;">0.175521</td></tr>
# <tr><td>GBM_1_AutoML_20190420_204025                       </td><td style="text-align: right;">0.756751</td><td style="text-align: right;"> 0.517751</td><td style="text-align: right;">              0.311608</td><td style="text-align: right;">0.417823</td><td style="text-align: right;">0.174576</td></tr>
# <tr><td>GBM_grid_1_AutoML_20
# 69         GBM_grid_1_AutoML_20190420_205020_model_14  0.593433   0.597061
# 70          GBM_grid_1_AutoML_20190420_204025_model_2  0.557181  13.622522
#
#     mean_per_class_error      rmse       mse
# 0               0.303151  0.418952  0.175521
# 1               0.311608  0.417823  0.174576
# 2               0.299041  0.413809  0.171238
# 3               0.288289  0.415966  0.173028
# 4               0.291218  0.416634  0.173584
# 5               0.295500  0.413658  0.171113
# 6               0.295500  0.413658  0.171113
# 7               0.295500  0.413658  0.171113
# 8               0.295500  0.413658  0.171113
# 9               0.294147  0.428805  0.183874
# 10              0.282653  0.421682  0.177815
# 11              0.317207  0.418369  0.175033
# 12              0.300243  0.417659  0.174439
# 13              0.295896  0.420039  0.176433
# 14              0.314033  0.423442  0.179303
# 15              0.295414  0.418382  0.175044
# 16              0.292398  0.416938  0.173838
# 17              0.292945  0.416855  0.173768
# 18              0.291787  0.424195  0.179941
# 19              0.302626  0.424584  0.180272
# 20              0.301186  0.417315  0.174152
# 21              0.304288  0.425840  0.181340
# 22              0.285100  0.442634  0.195925
# 23              0.297249  0.418303  0.174977
# 24              0.291218  0.417226  0.174078
# 25              0.299610  0.417956  0.174687
# 26              0.295983  0.428867  0.183927
# 27              0.307433  0.425893  0.181385
# 28              0.310845  0.425757  0.181269
# 29              0.303324  0.420731  0.177015
# ..                   ...       ...       ...
# 41              0.312874  0.420800  0.177073
# 42              0.302604  0.443225  0.196448
# 43              0.309225  0.428275  0.183419
# 44              0.312198  0.436448  0.190487
# 45              0.301992  0.420319  0.176668
# 46              0.317135  0.424793  0.180449
# 47              0.313903  0.425194  0.180790
# 48              0.305533  0.439409  0.193080
# 49              0.311039  0.443266  0.196484
# 50              0.306735  0.439305  0.192989
# 51              0.308678  0.424806  0.180460
# 52              0.290649  0.446561  0.199417
# 53              0.326995  0.469845  0.220754
# 54              0.308635  0.427287  0.182574
# 55              0.319193  0.430645  0.185455
# 56              0.309204  0.443549  0.196735
# 57              0.325397  0.474654  0.225297
# 58              0.310974  0.430416  0.185258
# 59              0.298365  0.425868  0.181364
# 60              0.325678  0.430359  0.185209
# 61              0.320395  0.437665  0.191550
# 62              0.338532  0.434363  0.188671
# 63              0.332897  0.437158  0.191107
# 64              0.375331  0.450400  0.202860
# 65              0.381405  0.450365  0.202829
# 66              0.375439  0.450683  0.203115
# 67              0.386825  0.451155  0.203541
# 68              0.386192  0.451211  0.203591
# 69              0.394627  0.451254  0.203630
# 70              0.500000  0.633028  0.400725
#
# [71 rows x 6 columns]

# %%
length = len(aml2_leaderboard_df)
length
meta_data["models_generated"] = length

# %%
# save leaderboard
leaderboard_stats=run_id+'_leaderboard.csv'
aml2_leaderboard_df.to_csv(leaderboard_stats)

# %%
aml2_leaderboard_df=aml2.leaderboard.as_data_frame()
model2_set=aml2_leaderboard_df['model_id']
model2_set
# Out:
# 0             GBM_grid_1_AutoML_20190420_204025_model_4
# 1                          GBM_1_AutoML_20190420_204025
# 2             GBM_grid_1_AutoML_20190420_203958_model_3
# 3     StackedEnsemble_BestOfFamily_AutoML_20190420_2...
# 4      StackedEnsemble_AllModels_AutoML_20190420_203958
# 5             GLM_grid_1_AutoML_20190420_203958_model_1
# 6             GLM_grid_1_AutoML_20190420_204025_model_1
# 7             GLM_grid_1_AutoML_20190420_204019_model_1
# 8            GBM_grid_1_AutoML_20190420_203958_model_14
# 9                          GBM_4_AutoML_20190420_203958
# 10            GBM_grid_1_AutoML_20190420_203958_model_4
# 11                         GBM_5_AutoML_20190420_203958
# 12                         GBM_3_AutoML_20190420_203958
# 13                         XRT_1_AutoML_20190420_204025
# 14                         GBM_5_AutoML_20190420_204025
# 15            GBM_grid_1_AutoML_20190420_204025_model_7
# 16            GBM_grid_1_AutoML_20190420_203958_model_1
# 17            GBM_grid_1_AutoML_20190420_204025_model_1
# 18                         GBM_1_AutoML_20190420_204019
# 19                         GBM_2_AutoML_20190420_203958
# 20                         GBM_2_AutoML_20190420_204025
# 21                         GBM_1_AutoML_20190420_203958
# 22            GBM_grid_1_AutoML_20190420_204025_model_9
# 23                         GBM_3_AutoML_20190420_204025
# 24           GBM_grid_1_AutoML_20190420_203958_model_13
# 25                         DRF_1_AutoML_20190420_204025
# 26            GBM_grid_1_AutoML_20190420_204025_model_8
# 27            GBM_grid_1_AutoML_20190420_204025_model_6
# 28                         GBM_4_AutoML_20190420_204025
# 29            GBM_grid_1_AutoML_20190420_203958_model_8
# 30           GBM_grid_1_AutoML_20190420_204025_model_10
# 31           GBM_grid_1_AutoML_20190420_203958_model_11
# 32            GBM_grid_1_AutoML_20190420_203958_model_5
# 33            GBM_grid_1_AutoML_20190420_204025_model_5
# 34                         DRF_1_AutoML_20190420_203958
# 35           GBM_grid_1_AutoML_20190420_203958_model_12
# 36            GBM_grid_1_AutoML_20190420_203958_model_2
# 37           GBM_grid_1_AutoML_20190420_203958_model_15
# 38            GBM_grid_1_AutoML_20190420_204025_model_3
# 39                         XRT_1_AutoML_20190420_203958
# 40                         DRF_1_AutoML_20190420_204019
# 41            GBM_grid_1_AutoML_20190420_203958_model_6
# 42            GBM_grid_1_AutoML_20190420_203958_model_7
# 43           GBM_grid_1_AutoML_20190420_203958_model_10
# 44            GBM_grid_1_AutoML_20190420_203958_model_9
# 45            GBM_grid_1_AutoML_20190420_204025_model_2
# Name: model_id, dtype: object

# %%
count = 0;
for i in model2_set:
    count = count+1;
for i in range(0,count):
    mod_best=h2o.get_model(model2_set[i])
    parameters = mod_best.params
    n= str((model2_set[i]))+'__300'
    dict_to_json(parameters,n)

# %%
# Update and save meta data
n=run_id+'_meta_data.json'
dict_to_json(meta_data,n)

# %%
meta_data
# Out:
# {'start_time': 1555807173.0831306,
#  'target': 'Dataset',
#  'server_path': 'C:\\Users\\Manvi\\Anaconda3\\indian-liver-patient-records',
#  'data_path': None,
#  'test_path': None,
#  'max_models': None,
#  'run_time': 300,
#  'run_id': 'nRidYg95h',
#  'scale': False,
#  'classification': True,
#  'model_path': None,
#  'balance': False,
#  'balance_threshold': 0.2,
#  'project': None,
#  'end_time': 1555807295.155993,
#  'execution_time': 122.07286238670349,
#  'run_path': 'C:\\Users\\Manvi\\Anaconda3\\indian-liver-patient-records\\nRidYg95h',
#  'nthreads': 1,
#  'min_mem_size': 0,
#  'analysis': 0,
#  'X': ['Age',
#   'Gender',
#   'Total_Bilirubin',
#   'Direct_Bilirubin',
#   'Alkaline_Phosphotase',
#   'Alamine_Aminotransferase',
#   'Aspartate_Aminotransferase',
#   'Total_Protiens',
#   'Albumin',
#   'Albumin_and_Globulin_Ratio'],
#  'models_generated': 46}
